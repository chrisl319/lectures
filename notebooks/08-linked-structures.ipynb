# %% [markdown]
# # Linked Structures
#
# ## Agenda
#
# 1. Motivation
# 2. Wishlist
# 3. Mechanisms
# 4. Linked Data Structures

# %% [markdown]
# ## 1. Motivation: built-in, array-backed list runtimes

# %% [markdown]
# What are the runtime complexities of some common operations for updating an array-backed list?

# %%
import matplotlib.pyplot as plt
import numpy as np
from timeit import timeit

# %% [markdown]
# ### Index-based update

# %%
size = 10_000

ts = [timeit('lst[{}] = None'.format(n),
             setup=f'lst = list(range({size}))',
             number=100)
      for n in range(0, size, 10)]

plt.plot(ts, 'ro');

# %% [markdown]
# ### Appending

# %%
ts = [timeit('lst.append(None)',
             setup=f'lst = list(range({n}))',
             number=10000)
      for n in np.linspace(1000, 100_000, 1000, dtype=int)]

plt.plot(ts, 'ro');

# %% [markdown]
# ### Insertion & Deletion

# %%
ns = np.linspace(100, 10000, 50, dtype=int)

# timing insertion at front
ins_ts = [timeit('lst.insert(0, None)',
                 setup=f'lst = list(range({n}))',
                 number=100)
          for n in ns]

# timing deletion at front
del_ts = [timeit('del lst[0]',
                 setup=f'lst = list(range({n}))',
                 number=100)
          for n in ns]

plt.plot(ns, ins_ts, 'go')
plt.plot(ns, del_ts, 'ro');

# %% [markdown]
# ### Concatenation

# %%
def concat1(lst1, lst2):
    for x in lst2:
        lst1.append(x)
    return lst1

def concat2(lst1, lst2):
    lst1.extend(lst2)
    return lst1

def concat3(lst1, lst2):
    return lst1 + lst2

# %%
ns = np.linspace(100, 10000, 50, dtype=int)

ts = [[timeit(f'{fn}(lst1, lst2)',
              setup=f'lst1 = list(range({n})); lst2 = list(range({n}))',
              number=100,
              globals=globals())
       for n in ns] 
      for fn in ('concat1', 'concat2', 'concat3')]

plt.plot(ns, ts[0], 'ro')
plt.plot(ns, ts[1], 'go')
plt.plot(ns, ts[2], 'bo');

# %% [markdown]
# ### Conclusion
#
# While index-based updates and appends are $O(1)$, operations that may require changing the relative positions of elements en masse (e.g., insertion, deletion, concatenation) are $O(N)$.
#
# This is due to the **monolithic, contiguous memory allocation** of the array used to hold references to elements in the list. (when you create an array they must be sequentially next to each other)

# %% [markdown]
# ## 2. Wishlist
#
# For applications that frequently perform operations such as insertions & deletions (which are inefficient in an array-backed list) we would like to have an improved storage mechanism that:
#
# - does **not** require monolithic, contiguous memory allocation,
# - supports flexible and efficient reorganization of substructures (e.g., for concatenation and relocation),
# - and allows us to build other commonly needed operations (e.g., for indexing, iteration, search) on top of it.

# %% [markdown]
# ## 3. Mechanisms

# %% [markdown]
# ### 3.1. Two-Element Lists

# %%
# data items
i1 = 'lions'
i2 = 'tigers'
i3 = 'bears'
i4 = 'oh, my'

# %%
# creating individual "links"
l1 = [i1, None]
l2 = [i2, None]
l3 = [i3, None]
l4 = [i4, None]

# %%
# link-ing them together
l1[1] = l2
l2[1] = l3
l3[1] = l4

# %%
# data access
head = l1
head[0]
# Out:
# 'lions'

# %%
head[1][0]
# Out:
# 'tigers'

# %%
head[1][1][1][0]
# Out:
# 'oh, my'

# %%
# iteration
def link_iterator(l):
    while l:    #while l is not None (not the last value)
        yield l[0]
        l = l[1]

# %%
for x in link_iterator(head):
    print(x)
# Out:
# lions
# tigers
# bears
# oh, my

# %%
list(link_iterator(head))
# Out:
# ['lions', 'tigers', 'bears', 'oh, my']

# %%
# prepending (adding to the beginning of the list) is O(1)
i0 = 'walruses'
l0 = [i0, head]
head = l0

# %%
for x in link_iterator(head):
    print(x)
# Out:
# walruses
# lions
# tigers
# bears
# oh, my

# %%
# insertion also O(1)
i2_5 = 'elephants'
l2_5 = [i2_5, l3]
l2[1] = l2_5

# %%
for x in link_iterator(head):
    print(x)
# Out:
# walruses
# lions
# tigers
# elephants
# bears
# oh, my

# %%
# deletion also O(1)
head = head[1]
l2[1] = l3

# %%
for x in link_iterator(head):
    print(x)
# Out:
# lions
# tigers
# bears
# oh, my

# %% [markdown]
# ### 3.2. "Node" objects

# %%
class Node:
    def __init__(self, val, next=None):
        self.val = val
        self.next = next

# %%
# manually constructing a list
n1 = Node(i1)
n2 = Node(i2)
n3 = Node(i3)
n4 = Node(i4)

n1.next = n2
n2.next = n3
n3.next = n4

# %%
# data access
head = n1

# %%
head.next.val
# Out:
# 'tigers'

# %%
head.next.next.next.val
# Out:
# 'oh, my'

# %%
# iteration
def node_iterator(n):
    while True:
        yield n.val
        n = n.next  #moves through to the next node

# %%
for x in node_iterator(head):
    print(x)
# Out:
# lions
# tigers
# bears
# oh, my
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 for x in node_iterator(head):
#       2     print(x)
#
# Cell In[38], line 4, in node_iterator(n)
#       2 def node_iterator(n):
#       3     while True:
# ----> 4         yield n.val
#       5         n = n.next
#
# AttributeError: 'NoneType' object has no attribute 'val'

# %% [markdown]
# ## 4. Linked Data Structures

# %% [markdown]
# ### 4.1 Linked List

# %%
class LinkedList:
    class Node:
        def __init__(self, val, next=None):
            self.val = val
            self.next = next

    def __init__(self):
        self.head = None    #list is empty
        
    def prepend(self, val):
        n = LinkedList.Node(val, self.head)
        n.next = self.head
        self.head = n
        
    def __iter__(self):
        n = self.head
        while n:
            yield n.val
            n = n.next
            
    def __repr__(self):
        return '[' + ', '.join(repr(x) for x in self) + ']'

# %%
l = LinkedList()
for x in range(10):
    l.prepend(x)
l
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1, 0]

# %% [markdown]
# ### 4.2 Binary Tree

# %%
class BinaryNode:
    def __init__(self, val, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
# an "expression tree" representing the arithmetic expression ((5+3)*(8-4))
t = BinaryNode('*')
t.left = BinaryNode('+')
t.left.left  = BinaryNode('5')
t.left.right = BinaryNode('3')
t.right = BinaryNode('-')
t.right.left  = BinaryNode('8')
t.right.right = BinaryNode('4')

# %%
def print_expr_tree(t):
    if t:
        if not t.val.isdigit():
            print('(', end='')
        print_expr_tree(t.left)
        print(t.val, end='')
        print_expr_tree(t.right)
        if not t.val.isdigit():
            print(')', end='')

# %%
print_expr_tree(t)

# %% [markdown]
# ### 4.3 N-ary Tree

# %%
class NaryNode:
    def __init__(self, val, n=2):
        self.val = val
        self.children = [None] * n
        
    def __getitem__(self, idx):
        return self.children[idx]
    
    def __setitem__(self, idx, val):
        self.children[idx] = val
        
    def __iter__(self):
        for c in self.children:
            yield c

# %%
root = NaryNode('Kingdoms', n=5)

root[0] = NaryNode('Animalia', n=35)
root[1] = NaryNode('Plantae', n=12)
root[2] = NaryNode('Fungi', n=7)
root[3] = NaryNode('Protista', n=5)
root[4] = NaryNode('Monera', n=5)

root[2][0] = NaryNode('Chytridiomycota')
root[2][1] = NaryNode('Blastocladiomycota')
root[2][2] = NaryNode('Glomeromycota')
root[2][3] = NaryNode('Ascomycota')
root[2][4] = NaryNode('Basidiomycota')
root[2][5] = NaryNode('Microsporidia')
root[2][6] = NaryNode('Neocallimastigomycota')

def tree_iter(root):
    if root:
        yield root.val
        for c in root:
            yield from tree_iter(c)

# %%
for x in tree_iter(root):
    print(x)
